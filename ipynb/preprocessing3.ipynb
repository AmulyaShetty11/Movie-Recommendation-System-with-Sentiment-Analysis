# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Extracting features of 2018 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
#January–March
df1.head()
# Out:
#          Opening  Opening.1                    Title  \
# 0  J A N U A R Y          5  Insidious: The Last Key
# 1  J A N U A R Y          5         The Strange Ones
# 2  J A N U A R Y         12             The Commuter
# 3  J A N U A R Y         12               Proud Mary
# 4  J A N U A R Y         12         Acts of Violence
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / S...
# 1                             Vertical Entertainment
# 2      Lionsgate / StudioCanal / The Picture Company
# 3                                        Screen Gems
# 4                                 Lionsgate Premiere
#
#                                        Cast and crew Ref.
# 0  Adam Robitel (director); Leigh Whannell (scree...  [2]
# 1  Christopher Radcliff (director/screenplay); La...  [3]
# 2  Jaume Collet-Serra (director); Byron Willinger...  [4]
# 3  Babak Najafi (director); John S. Newman, Chris...  [5]
# ...

# %%
#April–June
df2.head()
# Out:
#      Opening  Opening.1                       Title  \
# 0  A P R I L          6               A Quiet Place
# 1  A P R I L          6                    Blockers
# 2  A P R I L          6  You Were Never Really Here
# 3  A P R I L          6              Chappaquiddick
# 4  A P R I L          6          The Miracle Season
#
#                                   Production company  \
# 0  Paramount Pictures / Platinum Dunes / Sunday N...
# 1  Universal Pictures / Good Universe / Point Gre...
# 2                                     Amazon Studios
# 3                              Entertainment Studios
# 4                                   LD Entertainment
#
#                                        Cast and crew  Ref.
# 0  John Krasinski (director/screenplay); Bryan Wo...  [60]
# 1  Kay Cannon (director); Brian Kehoe, Jim Kehoe ...  [61]
# 2  Lynne Ramsay (director/screenplay); Joaquin Ph...  [62]
# 3  John Curran (director); Taylor Allen, Andrew L...  [63]
# ...

# %%
#July–September
df3.head()
# Out:
#    Opening  Opening.1                  Title  \
# 0  J U L Y          3  Who's Watching Oliver
# 1  J U L Y          4        The First Purge
# 2  J U L Y          6   Ant-Man and the Wasp
# 3  J U L Y          6    Sorry to Bother You
# 4  J U L Y          6                Whitney
#
#                                   Production company  \
# 0                 Motionpictures / Gravitas Ventures
# 1  Universal Pictures / Blumhouse Productions / P...
# 2  Marvel Studios / Walt Disney Studios Motion Pi...
# 3                                 Annapurna Pictures
# 4                     Roadside Attractions / Miramax
#
#                                        Cast and crew   Ref.
# 0  Richie Moore (director/screenplay); Raimund Hu...  [113]
# 1  Gerard McMurray (director); James DeMonaco (sc...  [114]
# 2  Peyton Reed (director); Chris McKenna, Erik So...  [115]
# 3  Boots Riley (director/screenplay); LaKeith Sta...  [116]
# 4  Kevin Macdonald (director/screenplay); Whitney...  [117]

# %%
#October–December
df4.head()
# Out:
#          Opening  Opening.1                            Title  \
# 0  O C T O B E R          5                            Venom
# 1  O C T O B E R          5                   A Star Is Born
# 2  O C T O B E R          5  The Great Buster: A Celebration
# 3  O C T O B E R         12                        First Man
# 4  O C T O B E R         12       Bad Times at the El Royale
#
#                                   Production company  \
# 0           Columbia Pictures / Marvel Entertainment
# 1       Warner Bros. Pictures / Peters Entertainment
# 2                                  Cohen Media Group
# 3  Universal Pictures / DreamWorks Pictures / Amb...
# 4                                   20th Century Fox
#
#                                        Cast and crew   Ref.
# 0  Ruben Fleischer (director); Jeff Pinkner, Scot...  [180]
# 1  Bradley Cooper (director/screenplay); Eric Rot...  [181]
# 2            Peter Bogdanovich (director/screenplay)  [182]
# ...

# %%
#combining all quaters
df = pd.concat([df1,pd.concat([df2,pd.concat([df3,df4],ignore_index=True)],ignore_index=True)], ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1                    Title  \
# 0      J A N U A R Y          5  Insidious: The Last Key
# 1      J A N U A R Y          5         The Strange Ones
# 2      J A N U A R Y         12             The Commuter
# 3      J A N U A R Y         12               Proud Mary
# 4      J A N U A R Y         12         Acts of Violence
# ..               ...        ...                      ...
# 236  D E C E M B E R         21               Second Act
# 237  D E C E M B E R         25          Holmes & Watson
# 238  D E C E M B E R         25                     Vice
# 239  D E C E M B E R         25      On the Basis of Sex
# 240  D E C E M B E R         25                Destroyer
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2        Lionsgate / StudioCanal / The Picture Company
# ...

# %%
# !pip install tmdbv3api

# %%
from tmdbv3api import TMDb
import requests
tmdb = TMDb()
tmdb.api_key = 'c2d38df4942ae26509d35515234808f8' #your api key will be here

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x) # search the movie from tmdb website
    movie_id = result[0].id # get the movie id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key)) # get information of that movie with the help of api and movie id
    data_json = response.json() # convert the response into json form
    if data_json['genres']: # if there is genre present for that movie then 
        genre_str = " "
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else: 
        np.NaN

# %% [markdown]
# ***Sample example (Example 0 of dataset) of the workflow for fetching genre :***
#
# ***result :***
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/PwI3EfasE9fVuXsmMu9ffJh0Re.jpg', 'genre_ids': [27, 9648, 53], 'id': 406563, 'original_language': 'en', 'original_title': 'Insidious: The Last Key', 'overview': 'Parapsychologist Elise Rainier and her team travel to Five Keys, NM, to investigate a man’s claim of a haunting. Terror soon strikes when Rainier realizes that the house he lives in was her family’s old home.', 'popularity': 45.769, 'poster_path': '/nb9fc9INMg8kQ8L7sE7XTNsZnUX.jpg', 'release_date': '2018-01-03', 'title': 'Insidious: The Last Key', 'video': False, 'vote_average': 6.3, 'vote_count': 2759}], 'total_pages': 1, 'total_results': 1}
#
# ***movie_id :***
# 406563
#
# ***data_json :***
# {'adult': False, 'backdrop_path': '/PwI3EfasE9fVuXsmMu9ffJh0Re.jpg', 'belongs_to_collection': {'id': 228446, 'name': 'Insidious Collection', 'poster_path': '/fct5wsWu6niDIGRIC4aWEsN5Npa.jpg', 'backdrop_path': '/5FrPZHgbbmTIq0oxpwSGqu5HyXC.jpg'}, 'budget': 10000000, 'genres': [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'name': 'Mystery'}, {'id': 53, 'name': 'Thriller'}], 'homepage': 'http://www.insidiousmovie.com', 'id': 406563, 'imdb_id': 'tt5726086', 'original_language': 'en', 'original_title': 'Insidious: The Last Key', 'overview': 'Parapsychologist Elise Rainier and her team travel to Five Keys, NM, to investigate a man’s claim of a haunting. Terror soon strikes when Rainier realizes that the house he lives in was her family’s old home.', 'popularity': 45.769, 'poster_path': '/nb9fc9INMg8kQ8L7sE7XTNsZnUX.jpg', 'production_companies': [{'id': 11341, 'logo_path': '/xytTBODEy3p20ksHL4Ftxr483Iv.png', 'name': 'Stage 6 Films', 'origin_country': 'US'}, {'id': 3172, 'logo_path': '/rzKluDcRkIwHZK2pHsiT667A2Kw.png', 'name': 'Blumhouse Productions', 'origin_country': 'US'}, {'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png', 'name': 'Universal Pictures', 'origin_country': 'US'}, {'id': 21223, 'logo_path': None, 'name': 'Solana Films', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2018-01-03', 'revenue': 167885588, 'runtime': 103, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Fear comes home.', 'title': 'Insidious: The Last Key', 'video': False, 'vote_average': 6.3, 'vote_count': 2759}
#
# ***genre_str :***
# 'Horror Mystery Thriller'

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df.head()
# Out:
#          Opening  Opening.1                    Title  \
# 0  J A N U A R Y          5  Insidious: The Last Key
# 1  J A N U A R Y          5         The Strange Ones
# 2  J A N U A R Y         12             The Commuter
# 3  J A N U A R Y         12               Proud Mary
# 4  J A N U A R Y         12         Acts of Violence
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / S...
# 1                             Vertical Entertainment
# 2      Lionsgate / StudioCanal / The Picture Company
# 3                                        Screen Gems
# 4                                 Lionsgate Premiere
#
#                                        Cast and crew Ref.
# 0  Adam Robitel (director); Leigh Whannell (scree...  [2]
# 1  Christopher Radcliff (director/screenplay); La...  [3]
# 2  Jaume Collet-Serra (director); Byron Willinger...  [4]
# 3  Babak Najafi (director); John S. Newman, Chris...  [5]
# ...

# %%
df_2018 = df[['Title','Cast and crew','genres']]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# C:\Users\amulya shetty\AppData\Local\Temp\ipykernel_6328\930721595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))

# %%
df_2018.head()
# Out:
#                      Title                                      Cast and crew  \
# 0  Insidious: The Last Key  Adam Robitel (director); Leigh Whannell (scree...
# 1         The Strange Ones  Christopher Radcliff (director/screenplay); La...
# 2             The Commuter  Jaume Collet-Serra (director); Byron Willinger...
# 3               Proud Mary  Babak Najafi (director); John S. Newman, Chris...
# 4         Acts of Violence  Brett Donowho (director); Nicolas Aaron Mezzan...
#
#                     genres                                      director_name
# 0  Horror Mystery Thriller                                       Adam Robitel
# 1            Drama Mystery  Christopher Radcliff (director/screenplay); La...
# 2  Action Thriller Mystery                                 Jaume Collet-Serra
# 3    Thriller Action Crime                                       Babak Najafi
# 4    Action Crime Thriller                                      Brett Donowho

# %%
def get_actor1(x):
    return (x.split('screenplay); ')[-1].split(', ')[0])

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x : get_actor1(x))
# Out:
# C:\Users\amulya shetty\AppData\Local\Temp\ipykernel_6328\1998695760.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x : get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split('screenplay); ')[-1]).split(', ')) < 2:
        return np.NAN
    else :
        return (x.split('screenplay); ')[-1].split(', ')[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\Users\amulya shetty\AppData\Local\Temp\ipykernel_6328\3672495884.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018.head()
# Out:
#                      Title                                      Cast and crew  \
# 0  Insidious: The Last Key  Adam Robitel (director); Leigh Whannell (scree...
# 1         The Strange Ones  Christopher Radcliff (director/screenplay); La...
# 2             The Commuter  Jaume Collet-Serra (director); Byron Willinger...
# 3               Proud Mary  Babak Najafi (director); John S. Newman, Chris...
# 4         Acts of Violence  Brett Donowho (director); Nicolas Aaron Mezzan...
#
#                     genres                                      director_name  \
# 0  Horror Mystery Thriller                                       Adam Robitel
# 1            Drama Mystery  Christopher Radcliff (director/screenplay); La...
# 2  Action Thriller Mystery                                 Jaume Collet-Serra
# 3    Thriller Action Crime                                       Babak Najafi
# 4    Action Crime Thriller                                      Brett Donowho
#
# ...

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      4
# actor_3_name     15
# genres            0
# movie_title       0
# dtype: int64

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']

# %%
new_df18
# Out:
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 236                                        Peter Segal
# 237                                         Etan Cohen
# 238                                         Adam McKay
# 239                                         Mimi Leder
# 240                                       Karyn Kusama
#
#                                    actor_1_name            actor_2_name  \
# 0                                     Lin Shaye           Angus Sampson
# 1    Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                   Liam Neeson            Vera Farmiga
# ...

# %% [markdown]
# ## Extracting features of 2019 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = pd.concat([df1,pd.concat([df2,pd.concat([df3,df4],ignore_index=True)],ignore_index=True)],ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1              Title  \
# 0      J A N U A R Y          4        Escape Room
# 1      J A N U A R Y          4         Rust Creek
# 2      J A N U A R Y          4   American Hangman
# 3      J A N U A R Y         11   A Dog's Way Home
# 4      J A N U A R Y         11         The Upside
# ..               ...        ...                ...
# 239  D E C E M B E R         25  Spies in Disguise
# 240  D E C E M B E R         25       Little Women
# 241  D E C E M B E R         25               1917
# 242  D E C E M B E R         25         Just Mercy
# 243  D E C E M B E R         27           Clemency
#
#                                     Production company  \
# 0                    Columbia Pictures / Original Film
# 1                       IFC Films / Lunacy Productions
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ...

# %%
df['genres'] = df['Title'].map(lambda x : get_genre(str(x)))

# %%
df_2019 = df[['Title','Cast and crew','genres']]

# %%
df_2019.head()
# Out:
#               Title                                      Cast and crew  \
# 0       Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1        Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2  American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3  A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4        The Upside  Neil Burger (director); Jon Hartmere (screenpl...
#
#                         genres
# 0      Horror Thriller Mystery
# 1  Thriller Drama Action Crime
# 2                     Thriller
# 3       Drama Adventure Family
# 4                 Comedy Drama

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x : get_director(str(x)))
# Out:
# C:\Users\amulya shetty\AppData\Local\Temp\ipykernel_6328\3119375035.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x : get_director(str(x)))

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\Users\amulya shetty\AppData\Local\Temp\ipykernel_6328\1562076556.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\Users\amulya shetty\AppData\Local\Temp\ipykernel_6328\3736213850.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      1
# actor_3_name     17
# genres            0
# movie_title       0
# dtype: int64

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']

# %%
new_df19
# Out:
#               director_name         actor_1_name          actor_2_name  \
# 0              Adam Robitel       Taylor Russell          Logan Miller
# 1               Jen McGowan    Hermione Corfield           Jay Paulson
# 2         Wilson Coneybeare    Donald Sutherland    Vincent Kartheiser
# 3      Charles Martin Smith  Bryce Dallas Howard    Edward James Olmos
# 4               Neil Burger       Bryan Cranston            Kevin Hart
# ..                      ...                  ...                   ...
# 239  Nick Bruno, Troy Quane           Will Smith           Tom Holland
# 240            Greta Gerwig        Saoirse Ronan           Emma Watson
# 241              Sam Mendes        George MacKay  Dean-Charles Chapman
# 242   Destin Daniel Cretton    Michael B. Jordan            Jamie Foxx
# 243         Chinonye Chukwu        Alfre Woodard        Wendell Pierce
#
#          actor_3_name                                    genres  \
# ...

# %%
my_df = pd.concat([new_df18,new_df19], ignore_index=True)

# %%
my_df
# Out:
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 480                             Nick Bruno, Troy Quane
# 481                                       Greta Gerwig
# 482                                         Sam Mendes
# 483                              Destin Daniel Cretton
# 484                                    Chinonye Chukwu
#
#                                    actor_1_name            actor_2_name  \
# 0                                     Lin Shaye           Angus Sampson
# 1    Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                   Liam Neeson            Vera Farmiga
# ...

# %%
old_df = pd.read_csv('../datasets/new_data.csv')

# %%
old_df
# Out:
#               director_name          actor_1_name            actor_2_name  \
# 0             James Cameron           CCH Pounder        Joel David Moore
# 1            Gore Verbinski           Johnny Depp           Orlando Bloom
# 2                Sam Mendes       Christoph Waltz            Rory Kinnear
# 3         Christopher Nolan             Tom Hardy          Christian Bale
# 4               Doug Walker           Doug Walker              Rob Walker
# ...                     ...                   ...                     ...
# 5370            Jim Strouse      Jessica Williams            Chris O'Dowd
# 5371            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 5372       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 5373  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 5374           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#               actor_3_name                           genres  \
# ...

# %%
final_df = pd.concat([old_df,my_df],ignore_index=True)

# %%
final_df
# Out:
#                director_name       actor_1_name          actor_2_name  \
# 0              James Cameron        CCH Pounder      Joel David Moore
# 1             Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                 Sam Mendes    Christoph Waltz          Rory Kinnear
# 3          Christopher Nolan          Tom Hardy        Christian Bale
# 4                Doug Walker        Doug Walker            Rob Walker
# ...                      ...                ...                   ...
# 5855  Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 5856            Greta Gerwig      Saoirse Ronan           Emma Watson
# 5857              Sam Mendes      George MacKay  Dean-Charles Chapman
# 5858   Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5859         Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#               actor_3_name                                    genres  \
# ...

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df.to_csv('../datasets/final_data.csv',index=False)
