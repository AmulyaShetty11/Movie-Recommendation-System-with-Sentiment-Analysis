# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Extracting features of 2020 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
# this two rows are going to coz further error coz tmbd doesn't have movie having this title
# you can also auttomate this process by modifying the function if present in huge number
print(df1['Title'][55])
print(df3['Title'][22])
df1.drop(index=55,inplace=True)
df3['Title'][22] = "The SpongeBob Movie: Sponge on the Run"
# Out:
# No films had been released on this date as resulting the closure of theaters caused by the COVID-19 pandemic
# The SpongeBob Movie: Sponge on the Run (Canadian theatrical release)
# C:\Users\amulya shetty\AppData\Local\Temp\ipykernel_1548\2040648851.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Title'][22] = "The SpongeBob Movie: Sponge on the Run"

# %%
#combining all quaters
df = pd.concat([df1,pd.concat([df2,pd.concat([df3,df4],ignore_index=True)],ignore_index=True)], ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1                  Title  \
# 0      J A N U A R Y          3             The Grudge
# 1      J A N U A R Y         10             Underwater
# 2      J A N U A R Y         10            Like a Boss
# 3      J A N U A R Y         10          Three Christs
# 4      J A N U A R Y         10      Inherit the Viper
# ..               ...        ...                    ...
# 269  D E C E M B E R         25       We Can Be Heroes
# 270  D E C E M B E R         25      News of the World
# 271  D E C E M B E R         25  One Night in Miami...
# 272  D E C E M B E R         25  Promising Young Woman
# 273  D E C E M B E R         30      Pieces of a Woman
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                   Paramount Pictures / Artists First
# 3                                            IFC Films
# 4    Lionsgate / Barry Films / Tycor International ...
# ..                                                 ...
# 269  Netflix / Troublemaker Studios / Double R Prod...
# 270        Universal Pictures / Perfect World Pictures
# 271                                     Amazon Studios
# 272          Focus Features / FilmNation Entertainment
# 273                             Netflix / Bron Studios
#
#                                          Cast and crew   Ref.
# 0    Nicolas Pesce (director/screenplay); Andrea Ri...    [2]
# 1    William Eubank (director); Brian Duffield, Ada...    [3]
# 2    Miguel Arteta (director); Sam Pitman, Adam Col...    [4]
# 3    Jon Avnet (director/screenplay); Eric Nazarian...    NaN
# 4    Anthony Jerjen (director); Andrew Crabtree (sc...    [5]
# ..                                                 ...    ...
# 269  Robert Rodriguez (director/screenplay); Priyan...  [243]
# 270  Paul Greengrass (director/screenplay); Luke Da...  [244]
# 271  Regina King (director); Kemp Powers (screenpla...  [245]
# 272  Emerald Fennell (director/screenplay); Carey M...  [246]
# 273  Kornél Mundruczó (director); Kata Wéber (scree...  [247]
#
# [274 rows x 6 columns]

# %%
from tmdbv3api import TMDb
import requests
tmdb = TMDb()
tmdb.api_key = '61eba94e833683f5a5dad5a53c3c9c4a' #your api key will be here

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df.head()
# Out:
#          Opening  Opening.1              Title  \
# 0  J A N U A R Y          3         The Grudge
# 1  J A N U A R Y         10         Underwater
# 2  J A N U A R Y         10        Like a Boss
# 3  J A N U A R Y         10      Three Christs
# 4  J A N U A R Y         10  Inherit the Viper
#
#                                   Production company  \
# 0  Screen Gems / Stage 6 Films / Ghost House Pict...
# 1  20th Century Fox / TSG Entertainment / Chernin...
# 2                 Paramount Pictures / Artists First
# 3                                          IFC Films
# 4  Lionsgate / Barry Films / Tycor International ...
#
#                                        Cast and crew Ref.  \
# 0  Nicolas Pesce (director/screenplay); Andrea Ri...  [2]
# 1  William Eubank (director); Brian Duffield, Ada...  [3]
# 2  Miguel Arteta (director); Sam Pitman, Adam Col...  [4]
# 3  Jon Avnet (director/screenplay); Eric Nazarian...  NaN
# 4  Anthony Jerjen (director); Andrew Crabtree (sc...  [5]
#
#                                     genres
# 0                           Horror Mystery
# 1  Horror Science Fiction Action Adventure
# 2                                   Comedy
# 3                                    Drama
# 4                     Crime Thriller Drama

# %%
df_2020 = df[['Title','Cast and crew','genres']]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(x))
# Out:
# C:\Users\amulya shetty\AppData\Local\Temp\ipykernel_1548\1089628015.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(x))

# %%
df_2020.head()
# Out:
#                Title                                      Cast and crew  \
# 0         The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1         Underwater  William Eubank (director); Brian Duffield, Ada...
# 2        Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3      Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4  Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
#
#                                     genres   director_name
# 0                           Horror Mystery   Nicolas Pesce
# 1  Horror Science Fiction Action Adventure  William Eubank
# 2                                   Comedy   Miguel Arteta
# 3                                    Drama       Jon Avnet
# 4                     Crime Thriller Drama  Anthony Jerjen

# %%
def get_actor1(x):
    return (x.split('screenplay); ')[-1].split(', ')[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x : get_actor1(x))
# Out:
# C:\Users\amulya shetty\AppData\Local\Temp\ipykernel_1548\2254483747.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x : get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split('screenplay); ')[-1]).split(', ')) < 2:
        return np.NAN
    else :
        return (x.split('screenplay); ')[-1].split(', ')[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\Users\amulya shetty\AppData\Local\Temp\ipykernel_1548\2876230040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2020.head()
# Out:
#                Title                                      Cast and crew  \
# 0         The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1         Underwater  William Eubank (director); Brian Duffield, Ada...
# 2        Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3      Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4  Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
#
#                                     genres   director_name  \
# 0                           Horror Mystery   Nicolas Pesce
# 1  Horror Science Fiction Action Adventure  William Eubank
# 2                                   Comedy   Miguel Arteta
# 3                                    Drama       Jon Avnet
# 4                     Crime Thriller Drama  Anthony Jerjen
#
#          actor_1_name       actor_2_name     actor_3_name
# 0  Andrea Riseborough      Demián Bichir         John Cho
# 1     Kristen Stewart     Vincent Cassel  Jessica Henwick
# 2     Tiffany Haddish         Rose Byrne      Salma Hayek
# 3        Richard Gere     Peter Dinklage   Walton Goggins
# 4       Josh Hartnett  Margarita Levieva   Chandler Riggs

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df20.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      4
# actor_3_name     27
# genres            0
# movie_title       0
# dtype: int64

# %%
new_df20['actor_2_name'] = new_df20['actor_2_name'].replace(np.nan, 'unknown')
new_df20['actor_3_name'] = new_df20['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 269  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 270   Paul Greengrass              Tom Hanks      Helena Zengel
# 271       Regina King      Kingsley Ben-Adir          Eli Goree
# 272   Emerald Fennell         Carey Mulligan         Bo Burnham
# 273  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                   genres  \
# 0           John Cho                           Horror Mystery
# 1    Jessica Henwick  Horror Science Fiction Action Adventure
# 2        Salma Hayek                                   Comedy
# 3     Walton Goggins                                    Drama
# 4     Chandler Riggs                     Crime Thriller Drama
# ..               ...                                      ...
# 269    YaYa Gosselin             Family Action Fantasy Comedy
# 270          unknown                  Drama Western Adventure
# 271      Aldis Hodge                                    Drama
# 272      Alison Brie                     Thriller Crime Drama
# 273     Molly Parker                                    Drama
#
#                movie_title                                               comb
# 0               the grudge  Andrea Riseborough Demián Bichir John Cho Nico...
# 1               underwater  Kristen Stewart Vincent Cassel Jessica Henwick...
# 2              like a boss  Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3            three christs  Richard Gere Peter Dinklage Walton Goggins Jon...
# 4        inherit the viper  Josh Hartnett Margarita Levieva Chandler Riggs...
# ..                     ...                                                ...
# 269       we can be heroes  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 270      news of the world  Tom Hanks Helena Zengel unknown Paul Greengras...
# 271  one night in miami...  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 272  promising young woman  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 273      pieces of a woman  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [274 rows x 7 columns]

# %% [markdown]
# ## Extracting features of 2021 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2021"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df3.drop(index=87,inplace= True)

# %%
df = pd.concat([df1,pd.concat([df2,pd.concat([df3,df4],ignore_index=True)],ignore_index=True)],ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1                            Title  \
# 0      J A N U A R Y        1.0              Shadow in the Cloud
# 1      J A N U A R Y        5.0                          Hacksaw
# 2      J A N U A R Y       12.0  Dr. Bird's Advice for Sad Poets
# 3      J A N U A R Y       13.0                  The White Tiger
# 4      J A N U A R Y       14.0                      Locked Down
# ..               ...        ...                              ...
# 358  D E C E M B E R       25.0           The Tragedy of Macbeth
# 359  D E C E M B E R       25.0             A Journal for Jordan
# 360  D E C E M B E R       25.0                American Underdog
# 361  D E C E M B E R       26.0                          Memoria
# 362  D E C E M B E R        NaN                              NaN
#
#                                     Production company  \
# 0                               Vertical Entertainment
# 1                     Leone Films / Midnight Releasing
# 2             Relativity Media / Ketchup Entertainment
# 3             Netflix / ARRAY / Purple Pebble Pictures
# 4                      HBO Max / Warner Bros. Pictures
# ..                                                 ...
# 358                        Apple TV+ / A24 / IAC Films
# 359  Columbia Pictures / Escape Artists / Bron Studios
# 360                                          Lionsgate
# 361                                               Neon
# 362                                                NaN
#
#                                          Cast and crew   Ref.
# 0    Roseanne Liang (director/screenplay); Max Land...    [2]
# 1    Anthony Leone (director/screenplay); Amy Cay, ...    [3]
# 2    Yaniv Raz (director/screenplay); Lucas Jade Zu...    [4]
# 3    Ramin Bahrani (director/screenplay); Adarsh Go...    NaN
# 4    Doug Liman (director); Steven Knight (screenpl...    [5]
# ..                                                 ...    ...
# 358  Joel Coen (director/screenplay); Denzel Washin...  [276]
# 359  Denzel Washington (director); Virgil Williams ...  [277]
# 360  Erwin brothers (directors); Jon Erwin, David A...  [278]
# 361  Apichatpong Weerasethakul (director/acreenplay...  [279]
# 362                                                NaN    NaN
#
# [363 rows x 6 columns]

# %%
df['genres'] = df['Title'].map(lambda x : get_genre(str(x)))

# %%
df_2021 = df[['Title','Cast and crew','genres']]

# %%
df_2021.head()
# Out:
#                              Title  \
# 0              Shadow in the Cloud
# 1                          Hacksaw
# 2  Dr. Bird's Advice for Sad Poets
# 3                  The White Tiger
# 4                      Locked Down
#
#                                        Cast and crew                genres
# 0  Roseanne Liang (director/screenplay); Max Land...     Horror Action War
# 1  Anthony Leone (director/screenplay); Amy Cay, ...                Horror
# 2  Yaniv Raz (director/screenplay); Lucas Jade Zu...          Comedy Drama
# 3  Ramin Bahrani (director/screenplay); Adarsh Go...                 Drama
# 4  Doug Liman (director); Steven Knight (screenpl...  Comedy Crime Romance

# %%
df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x : get_director(str(x)))
# Out:
# C:\Users\amulya shetty\AppData\Local\Temp\ipykernel_1548\3339048921.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x : get_director(str(x)))

# %%
df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# C:\Users\amulya shetty\AppData\Local\Temp\ipykernel_1548\1611661901.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# C:\Users\amulya shetty\AppData\Local\Temp\ipykernel_1548\3001516348.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
df_2021['actor_3_name'] = df_2021['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2021 = df_2021.rename(columns={'Title':'movie_title'})

# %%
new_df21 = df_2021.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df21.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      8
# actor_3_name     26
# genres            0
# movie_title       1
# dtype: int64

# %%
new_df21['actor_2_name'] = new_df21['actor_2_name'].replace(np.nan, 'unknown')
new_df21['actor_3_name'] = new_df21['actor_3_name'].replace(np.nan, 'unknown')
new_df21.dropna(inplace=True)

# %%
new_df21.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# dtype: int64

# %%
new_df21['movie_title'] = new_df21['movie_title'].str.lower()

# %%
new_df21['comb'] = new_df21['actor_1_name'] + ' ' + new_df21['actor_2_name'] + ' '+ new_df21['actor_3_name'] + ' '+ new_df21['director_name'] +' ' + new_df21['genres']

# %%
new_df21
# Out:
#                                          director_name  \
# 0                                       Roseanne Liang
# 1                                        Anthony Leone
# 2                                            Yaniv Raz
# 3                                        Ramin Bahrani
# 4                                           Doug Liman
# ..                                                 ...
# 357                                     Matthew Vaughn
# 358                                          Joel Coen
# 359                                  Denzel Washington
# 360                                     Erwin brothers
# 361  Apichatpong Weerasethakul (director/acreenplay...
#
#                                           actor_1_name          actor_2_name  \
# 0                                   Chloë Grace Moretz     Taylor John Smith
# 1                                              Amy Cay  Brian Patrick Butler
# 2                                    Lucas Jade Zumann        Taylor Russell
# 3                                        Adarsh Gourav         Rajkummar Rao
# 4                                        Anne Hathaway      Chiwetel Ejiofor
# ..                                                 ...                   ...
# 357                                      Ralph Fiennes        Gemma Arterton
# 358                                  Denzel Washington     Frances McDormand
# 359                                  Michael B. Jordan          Chanté Adams
# 360                                       Zachary Levi           Anna Paquin
# 361  Apichatpong Weerasethakul (director/acreenplay...            Elkin Díaz
#
#               actor_3_name                            genres  \
# 0             Beulah Koale                 Horror Action War
# 1       Michael C. Burgess                            Horror
# 2             Chase Stokes                      Comedy Drama
# 3    Priyanka Chopra Jonas                             Drama
# 4         Stephen Merchant              Comedy Crime Romance
# ..                     ...                               ...
# 357             Rhys Ifans  Action Comedy Adventure Thriller
# 358          Bertie Carvel                         Drama War
# 359        Jalon Christian                     Drama Romance
# 360           Dennis Quaid                             Drama
# 361         Jeanne Balibar     Drama Science Fiction Mystery
#
#                          movie_title  \
# 0                shadow in the cloud
# 1                            hacksaw
# 2    dr. bird's advice for sad poets
# 3                    the white tiger
# 4                        locked down
# ..                               ...
# 357                   the king's man
# 358           the tragedy of macbeth
# 359             a journal for jordan
# 360                american underdog
# 361                          memoria
#
#                                                   comb
# 0    Chloë Grace Moretz Taylor John Smith Beulah Ko...
# 1    Amy Cay Brian Patrick Butler Michael C. Burges...
# 2    Lucas Jade Zumann Taylor Russell Chase Stokes ...
# 3    Adarsh Gourav Rajkummar Rao Priyanka Chopra Jo...
# 4    Anne Hathaway Chiwetel Ejiofor Stephen Merchan...
# ..                                                 ...
# 357  Ralph Fiennes Gemma Arterton Rhys Ifans Matthe...
# 358  Denzel Washington Frances McDormand Bertie Car...
# 359  Michael B. Jordan Chanté Adams Jalon Christian...
# 360  Zachary Levi Anna Paquin Dennis Quaid Erwin br...
# 361  Apichatpong Weerasethakul (director/acreenplay...
#
# [362 rows x 7 columns]

# %%
my_df = pd.concat([new_df20,new_df21], ignore_index=True)

# %%
my_df
# Out:
#                                          director_name  \
# 0                                        Nicolas Pesce
# 1                                       William Eubank
# 2                                        Miguel Arteta
# 3                                            Jon Avnet
# 4                                       Anthony Jerjen
# ..                                                 ...
# 631                                     Matthew Vaughn
# 632                                          Joel Coen
# 633                                  Denzel Washington
# 634                                     Erwin brothers
# 635  Apichatpong Weerasethakul (director/acreenplay...
#
#                                           actor_1_name       actor_2_name  \
# 0                                   Andrea Riseborough      Demián Bichir
# 1                                      Kristen Stewart     Vincent Cassel
# 2                                      Tiffany Haddish         Rose Byrne
# 3                                         Richard Gere     Peter Dinklage
# 4                                        Josh Hartnett  Margarita Levieva
# ..                                                 ...                ...
# 631                                      Ralph Fiennes     Gemma Arterton
# 632                                  Denzel Washington  Frances McDormand
# 633                                  Michael B. Jordan       Chanté Adams
# 634                                       Zachary Levi        Anna Paquin
# 635  Apichatpong Weerasethakul (director/acreenplay...         Elkin Díaz
#
#         actor_3_name                                   genres  \
# 0           John Cho                           Horror Mystery
# 1    Jessica Henwick  Horror Science Fiction Action Adventure
# 2        Salma Hayek                                   Comedy
# 3     Walton Goggins                                    Drama
# 4     Chandler Riggs                     Crime Thriller Drama
# ..               ...                                      ...
# 631       Rhys Ifans         Action Comedy Adventure Thriller
# 632    Bertie Carvel                                Drama War
# 633  Jalon Christian                            Drama Romance
# 634     Dennis Quaid                                    Drama
# 635   Jeanne Balibar            Drama Science Fiction Mystery
#
#                 movie_title                                               comb
# 0                the grudge  Andrea Riseborough Demián Bichir John Cho Nico...
# 1                underwater  Kristen Stewart Vincent Cassel Jessica Henwick...
# 2               like a boss  Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3             three christs  Richard Gere Peter Dinklage Walton Goggins Jon...
# 4         inherit the viper  Josh Hartnett Margarita Levieva Chandler Riggs...
# ..                      ...                                                ...
# 631          the king's man  Ralph Fiennes Gemma Arterton Rhys Ifans Matthe...
# 632  the tragedy of macbeth  Denzel Washington Frances McDormand Bertie Car...
# 633    a journal for jordan  Michael B. Jordan Chanté Adams Jalon Christian...
# 634       american underdog  Zachary Levi Anna Paquin Dennis Quaid Erwin br...
# 635                 memoria  Apichatpong Weerasethakul (director/acreenplay...
#
# [636 rows x 7 columns]

# %%
old_df = pd.read_csv('../datasets/final_data.csv')

# %%
old_df
# Out:
#                director_name       actor_1_name          actor_2_name  \
# 0              James Cameron        CCH Pounder      Joel David Moore
# 1             Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                 Sam Mendes    Christoph Waltz          Rory Kinnear
# 3          Christopher Nolan          Tom Hardy        Christian Bale
# 4                Doug Walker        Doug Walker            Rob Walker
# ...                      ...                ...                   ...
# 5855  Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 5856            Greta Gerwig      Saoirse Ronan           Emma Watson
# 5857              Sam Mendes      George MacKay  Dean-Charles Chapman
# 5858   Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5859         Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#               actor_3_name                                    genres  \
# 0                Wes Studi           Action|Adventure|Fantasy|Sci-Fi
# 1           Jack Davenport                  Action|Adventure|Fantasy
# 2         Stephanie Sigman                 Action|Adventure|Thriller
# 3     Joseph Gordon-Levitt                           Action|Thriller
# 4                  unknown                               Documentary
# ...                    ...                                       ...
# 5855         Rashida Jones  Animation Action Adventure Comedy Family
# 5856         Florence Pugh                             Drama Romance
# 5857           Mark Strong                          War Action Drama
# 5858           Brie Larson                       Drama Crime History
# 5859           Aldis Hodge                                     Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5855                                  spies in disguise
# 5856                                       little women
# 5857                                               1917
# 5858                                         just mercy
# 5859                                           clemency
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5855  Will Smith Tom Holland Rashida Jones Nick Brun...
# 5856  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5857  George MacKay Dean-Charles Chapman Mark Strong...
# 5858  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5859  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [5860 rows x 7 columns]

# %%
final_df = pd.concat([old_df,my_df],ignore_index=True)

# %%
final_df
# Out:
#                                           director_name  \
# 0                                         James Cameron
# 1                                        Gore Verbinski
# 2                                            Sam Mendes
# 3                                     Christopher Nolan
# 4                                           Doug Walker
# ...                                                 ...
# 6491                                     Matthew Vaughn
# 6492                                          Joel Coen
# 6493                                  Denzel Washington
# 6494                                     Erwin brothers
# 6495  Apichatpong Weerasethakul (director/acreenplay...
#
#                                            actor_1_name       actor_2_name  \
# 0                                           CCH Pounder   Joel David Moore
# 1                                           Johnny Depp      Orlando Bloom
# 2                                       Christoph Waltz       Rory Kinnear
# 3                                             Tom Hardy     Christian Bale
# 4                                           Doug Walker         Rob Walker
# ...                                                 ...                ...
# 6491                                      Ralph Fiennes     Gemma Arterton
# 6492                                  Denzel Washington  Frances McDormand
# 6493                                  Michael B. Jordan       Chanté Adams
# 6494                                       Zachary Levi        Anna Paquin
# 6495  Apichatpong Weerasethakul (director/acreenplay...         Elkin Díaz
#
#               actor_3_name                            genres  \
# 0                Wes Studi   Action|Adventure|Fantasy|Sci-Fi
# 1           Jack Davenport          Action|Adventure|Fantasy
# 2         Stephanie Sigman         Action|Adventure|Thriller
# 3     Joseph Gordon-Levitt                   Action|Thriller
# 4                  unknown                       Documentary
# ...                    ...                               ...
# 6491            Rhys Ifans  Action Comedy Adventure Thriller
# 6492         Bertie Carvel                         Drama War
# 6493       Jalon Christian                     Drama Romance
# 6494          Dennis Quaid                             Drama
# 6495        Jeanne Balibar     Drama Science Fiction Mystery
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6491                                     the king's man
# 6492                             the tragedy of macbeth
# 6493                               a journal for jordan
# 6494                                  american underdog
# 6495                                            memoria
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 6491  Ralph Fiennes Gemma Arterton Rhys Ifans Matthe...
# 6492  Denzel Washington Frances McDormand Bertie Car...
# 6493  Michael B. Jordan Chanté Adams Jalon Christian...
# 6494  Zachary Levi Anna Paquin Dennis Quaid Erwin br...
# 6495  Apichatpong Weerasethakul (director/acreenplay...
#
# [6496 rows x 7 columns]

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df.duplicated().sum()
# Out:
# 1

# %%
final_df.drop_duplicates(subset ="movie_title", keep = 'last', inplace = True)

# %%
final_df.duplicated().sum()
# Out:
# 0

# %%
final_df
# Out:
#                                           director_name  \
# 0                                         James Cameron
# 1                                        Gore Verbinski
# 2                                            Sam Mendes
# 3                                     Christopher Nolan
# 4                                           Doug Walker
# ...                                                 ...
# 6491                                     Matthew Vaughn
# 6492                                          Joel Coen
# 6493                                  Denzel Washington
# 6494                                     Erwin brothers
# 6495  Apichatpong Weerasethakul (director/acreenplay...
#
#                                            actor_1_name       actor_2_name  \
# 0                                           CCH Pounder   Joel David Moore
# 1                                           Johnny Depp      Orlando Bloom
# 2                                       Christoph Waltz       Rory Kinnear
# 3                                             Tom Hardy     Christian Bale
# 4                                           Doug Walker         Rob Walker
# ...                                                 ...                ...
# 6491                                      Ralph Fiennes     Gemma Arterton
# 6492                                  Denzel Washington  Frances McDormand
# 6493                                  Michael B. Jordan       Chanté Adams
# 6494                                       Zachary Levi        Anna Paquin
# 6495  Apichatpong Weerasethakul (director/acreenplay...         Elkin Díaz
#
#               actor_3_name                            genres  \
# 0                Wes Studi   Action|Adventure|Fantasy|Sci-Fi
# 1           Jack Davenport          Action|Adventure|Fantasy
# 2         Stephanie Sigman         Action|Adventure|Thriller
# 3     Joseph Gordon-Levitt                   Action|Thriller
# 4                  unknown                       Documentary
# ...                    ...                               ...
# 6491            Rhys Ifans  Action Comedy Adventure Thriller
# 6492         Bertie Carvel                         Drama War
# 6493       Jalon Christian                     Drama Romance
# 6494          Dennis Quaid                             Drama
# 6495        Jeanne Balibar     Drama Science Fiction Mystery
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6491                                     the king's man
# 6492                             the tragedy of macbeth
# 6493                               a journal for jordan
# 6494                                  american underdog
# 6495                                            memoria
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 6491  Ralph Fiennes Gemma Arterton Rhys Ifans Matthe...
# 6492  Denzel Washington Frances McDormand Bertie Car...
# 6493  Michael B. Jordan Chanté Adams Jalon Christian...
# 6494  Zachary Levi Anna Paquin Dennis Quaid Erwin br...
# 6495  Apichatpong Weerasethakul (director/acreenplay...
#
# [6457 rows x 7 columns]

# %%
final_df.to_csv('../datasets/grandfinal_data.csv',index=False)
